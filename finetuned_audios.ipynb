# %%
from pydub import AudioSegment
import os

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from pydub import AudioSegment
import os

# Path where your .mp3 files are stored
mp3_dir = "/content/drive/MyDrive/fine_tune_data/audio_files/help_me_audio_mp3"
wav_dir = "/content/drive/MyDrive/fine_tune_data/audio_wav"

# Create target folder if it doesn't exist
os.makedirs(wav_dir, exist_ok=True)

# Convert all mp3 files
for file in os.listdir(mp3_dir):
    if file.endswith(".mp3") or file.endswith(".m4a"):
        mp3_path = os.path.join(mp3_dir, file)
        wav_path = os.path.join(wav_dir, os.path.splitext(file)[0] + ".wav")

        # Load and convert
        audio = AudioSegment.from_file(mp3_path)
        audio = audio.set_channels(1)        # mono
        audio = audio.set_frame_rate(16000)  # 16kHz
        audio.export(wav_path, format="wav")
        print(f"✅ Converted: {file} → {wav_path}")
# Out:
# ✅ Converted: 2020-10-29-21-41-22.mp3 → /content/drive/MyDrive/fine_tune_data/audio_wav/2020-10-29-21-41-22.wav
# ✅ Converted: help girl 1.m4a → /content/drive/MyDrive/fine_tune_data/audio_wav/help girl 1.wav
# ✅ Converted: help girl 2.m4a → /content/drive/MyDrive/fine_tune_data/audio_wav/help girl 2.wav
# ✅ Converted: help girl 3.m4a → /content/drive/MyDrive/fine_tune_data/audio_wav/help girl 3.wav
# ✅ Converted: help girl 4.m4a → /content/drive/MyDrive/fine_tune_data/audio_wav/help girl 4.wav
# ✅ Converted: help girl 5.m4a → /content/drive/MyDrive/fine_tune_data/audio_wav/help girl 5.wav
# ✅ Converted: help girl 6.m4a → /content/drive/MyDrive/fine_tune_data/audio_wav/help girl 6.wav
# ✅ Converted: 076904_hello-can-i-help-you-38120.mp3 → /content/drive/MyDrive/fine_tune_data/audio_wav/076904_hello-can-i-help-you-38120.wav
# ✅ Converted: help girl 18.m4a → /content/drive/MyDrive/fine_tune_data/audio_wav/help girl 18.wav
# ✅ Converted: help girl 17.m4a → /content/drive/MyDrive/fine_tune_data/audio_wav/help girl 17.wav
# ✅ Converted: help girl 13.m4a → /content/drive/MyDrive/fine_tune_data/audio_wav/help girl 13.wav
# ✅ Converted: help girl 14.m4a → /content/drive/MyDrive/fine_tune_data/audio_wav/help girl 14.wav
# ✅ Converted: help girl 16.m4a → /content/drive/MyDrive/fine_tune_data/audio_wav/help girl 16.wav
# ✅ Converted: help girl 15.m4a → /content/drive/MyDrive/fine_tune_data/audio_wav/help girl 15.wav
# ✅ Converted: help girl 11.m4a → /content/drive/MyDrive/fine_tune_data/audio_wav/help girl 11.wav
# ✅ Converted: help girl 12.m4a → /content/drive/MyDrive/fine_tune_data/audio_wav/help girl 12.wav
# ✅ Converted: help girl 9.m4a → /content/drive/MyDrive/fine_tune_data/audio_wav/help girl 9.wav
# ✅ Converted: help girl 10.m4a → /content/drive/MyDrive/fine_tune_data/audio_wav/help girl 10.wav
# ✅ Converted: help girl 8.m4a → /content/drive/MyDrive/fine_tune_data/audio_wav/help girl 8.wav
# ✅ Converted: help girl 7.m4a → /content/drive/MyDrive/fine_tune_data/audio_wav/help girl 7.wav
# ✅ Converted: New Recording 9.m4a → /content/drive/MyDrive/fine_tune_data/audio_wav/New Recording 9.wav
# ✅ Converted: New Recording 6.m4a → /content/drive/MyDrive/fine_tune_data/audio_wav/New Recording 6.wav
# ✅ Converted: New Recording 5.m4a → /content/drive/MyDrive/fine_tune_data/audio_wav/New Recording 5.wav
# ✅ Converted: muffled_cry-83102.mp3 → /content/drive/MyDrive/fine_tune_data/audio_wav/muffled_cry-83102.wav
# ✅ Converted: help-help-322552.mp3 → /content/drive/MyDrive/fine_tune_data/audio_wav/help-help-322552.wav
# ✅ Converted: New Recording 3.m4a → /content/drive/MyDrive/fine_tune_data/audio_wav/New Recording 3.wav
# ✅ Converted: help-me_mp3-54969.mp3 → /content/drive/MyDrive/fine_tune_data/audio_wav/help-me_mp3-54969.wav
# ✅ Converted: help-help-2-322551.mp3 → /content/drive/MyDrive/fine_tune_data/audio_wav/help-help-2-322551.wav
# ✅ Converted: New Recording 2.m4a → /content/drive/MyDrive/fine_tune_data/audio_wav/New Recording 2.wav
# ✅ Converted: New Recording 4.m4a → /content/drive/MyDrive/fine_tune_data/audio_wav/New Recording 4.wav
# ✅ Converted: help-echo-81995.mp3 → /content/drive/MyDrive/fine_tune_data/audio_wav/help-echo-81995.wav
# ✅ Converted: New Recording 22.m4a → /content/drive/MyDrive/fine_tune_data/audio_wav/New Recording 22.wav
# ✅ Converted: New Recording 19.m4a → /content/drive/MyDrive/fine_tune_data/audio_wav/New Recording 19.wav
# ✅ Converted: New Recording 20.m4a → /content/drive/MyDrive/fine_tune_data/audio_wav/New Recording 20.wav
# ✅ Converted: New Recording 17.m4a → /content/drive/MyDrive/fine_tune_data/audio_wav/New Recording 17.wav
# ✅ Converted: New Recording 18.m4a → /content/drive/MyDrive/fine_tune_data/audio_wav/New Recording 18.wav
# ✅ Converted: New Recording 16.m4a → /content/drive/MyDrive/fine_tune_data/audio_wav/New Recording 16.wav
# ✅ Converted: New Recording 15.m4a → /content/drive/MyDrive/fine_tune_data/audio_wav/New Recording 15.wav
# ✅ Converted: New Recording 10.m4a → /content/drive/MyDrive/fine_tune_data/audio_wav/New Recording 10.wav
# ✅ Converted: New Recording 13.m4a → /content/drive/MyDrive/fine_tune_data/audio_wav/New Recording 13.wav
# ✅ Converted: New Recording 14.m4a → /content/drive/MyDrive/fine_tune_data/audio_wav/New Recording 14.wav
# ✅ Converted: New Recording 11.m4a → /content/drive/MyDrive/fine_tune_data/audio_wav/New Recording 11.wav
# ✅ Converted: New Recording 12.m4a → /content/drive/MyDrive/fine_tune_data/audio_wav/New Recording 12.wav
# ✅ Converted: New Recording 7.m4a → /content/drive/MyDrive/fine_tune_data/audio_wav/New Recording 7.wav
# ✅ Converted: New Recording 8.m4a → /content/drive/MyDrive/fine_tune_data/audio_wav/New Recording 8.wav
# ✅ Converted: New Recording.m4a → /content/drive/MyDrive/fine_tune_data/audio_wav/New Recording.wav
# ✅ Converted: New Recording 38.m4a → /content/drive/MyDrive/fine_tune_data/audio_wav/New Recording 38.wav
# ✅ Converted: New Recording 37.m4a → /content/drive/MyDrive/fine_tune_data/audio_wav/New Recording 37.wav
# ✅ Converted: New Recording 36.m4a → /content/drive/MyDrive/fine_tune_data/audio_wav/New Recording 36.wav
# ✅ Converted: New Recording 35.m4a → /content/drive/MyDrive/fine_tune_data/audio_wav/New Recording 35.wav
# ✅ Converted: New Recording 31.m4a → /content/drive/MyDrive/fine_tune_data/audio_wav/New Recording 31.wav
# ✅ Converted: New Recording 33.m4a → /content/drive/MyDrive/fine_tune_data/audio_wav/New Recording 33.wav
# ✅ Converted: New Recording 32.m4a → /content/drive/MyDrive/fine_tune_data/audio_wav/New Recording 32.wav
# ✅ Converted: New Recording 34.m4a → /content/drive/MyDrive/fine_tune_data/audio_wav/New Recording 34.wav
# ✅ Converted: New Recording 27.m4a → /content/drive/MyDrive/fine_tune_data/audio_wav/New Recording 27.wav
# ✅ Converted: New Recording 30.m4a → /content/drive/MyDrive/fine_tune_data/audio_wav/New Recording 30.wav
# ✅ Converted: New Recording 29.m4a → /content/drive/MyDrive/fine_tune_data/audio_wav/New Recording 29.wav
# ✅ Converted: New Recording 28.m4a → /content/drive/MyDrive/fine_tune_data/audio_wav/New Recording 28.wav
# ✅ Converted: New Recording 26.m4a → /content/drive/MyDrive/fine_tune_data/audio_wav/New Recording 26.wav
# ✅ Converted: New Recording 25.m4a → /content/drive/MyDrive/fine_tune_data/audio_wav/New Recording 25.wav
# ✅ Converted: New Recording 23.m4a → /content/drive/MyDrive/fine_tune_data/audio_wav/New Recording 23.wav
# ✅ Converted: New Recording 24.m4a → /content/drive/MyDrive/fine_tune_data/audio_wav/New Recording 24.wav
# ✅ Converted: New Recording 21.m4a → /content/drive/MyDrive/fine_tune_data/audio_wav/New Recording 21.wav

# %%
import librosa
import numpy as np
import soundfile as sf
import random
import os

# Path to your original scream files
input_dir = '/content/drive/MyDrive/fine_tune_data/audio_wav/'
output_dir = '/content/drive/MyDrive/fine_tune_data/audio_augmented/'

# Create output directory if doesn't exist
os.makedirs(output_dir, exist_ok=True)

# Function to apply volume change
def change_volume(audio, factor):
    return audio * factor

# Function to apply pitch shift
def shift_pitch(audio, sr, n_steps):
    return librosa.effects.pitch_shift(y=audio, sr=sr, n_steps=n_steps)

# Function to add background noise
def add_noise(audio, noise_factor=0.005):
    noise = np.random.randn(len(audio))
    augmented_audio = audio + noise_factor * noise
    return augmented_audio

# Function to augment audio
def augment_audio(file_path, output_path, sr=16000):
    # Load original audio
    audio, sr = librosa.load(file_path, sr=sr)

    # Randomly apply augmentations
    if random.random() > 0.5:  # Apply volume change with a random factor
        audio = change_volume(audio, random.uniform(0.7, 1.5))

    if random.random() > 0.5:  # Apply pitch shift
        audio = shift_pitch(audio, sr, random.randint(-3, 3))

    if random.random() > 0.5:  # Add background noise
        audio = add_noise(audio)

    # Save augmented file
    sf.write(output_path, audio, sr)

# Process each scream file
for i, file_name in enumerate(os.listdir(input_dir)):
    if file_name.endswith('.wav'):
        file_path = os.path.join(input_dir, file_name)
        for j in range(2):  # Create 2 augmented versions per original file
            output_path = os.path.join(output_dir, f"augmented_{i}_{j}.wav")
            augment_audio(file_path, output_path)
            print(f"✅ Augmented: {output_path}")
# Out:
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_0_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_0_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_1_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_1_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_2_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_2_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_3_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_3_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_4_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_4_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_5_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_5_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_6_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_6_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_7_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_7_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_8_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_8_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_9_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_9_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_10_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_10_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_11_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_11_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_12_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_12_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_13_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_13_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_14_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_14_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_15_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_15_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_16_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_16_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_17_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_17_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_18_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_18_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_19_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_19_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_20_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_20_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_21_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_21_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_22_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_22_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_23_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_23_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_24_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_24_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_25_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_25_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_26_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_26_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_27_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_27_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_28_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_28_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_29_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_29_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_30_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_30_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_31_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_31_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_32_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_32_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_33_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_33_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_34_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_34_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_35_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_35_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_36_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_36_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_37_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_37_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_38_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_38_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_39_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_39_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_40_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_40_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_41_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_41_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_42_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_42_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_43_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_43_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_44_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_44_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_45_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_45_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_46_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_46_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_47_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_47_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_48_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_48_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_49_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_49_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_50_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_50_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_51_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_51_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_52_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_52_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_53_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_53_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_54_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_54_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_55_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_55_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_56_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_56_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_57_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_57_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_58_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_58_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_59_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_59_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_60_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_60_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_61_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_61_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_62_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/audio_augmented/augmented_62_1.wav

# %%
from pydub import AudioSegment
import os

# Your input and output paths
aac_dir = "/content/drive/MyDrive/fine_tune_data/audio_files/Scream_audiomp3"
wav_dir = "/content/drive/MyDrive/fine_tune_data/scream_wav"

# Create output directory if it doesn't exist
os.makedirs(wav_dir, exist_ok=True)

# Convert each .aac file
for filename in os.listdir(aac_dir):
    if filename.endswith(".mp3") or filename.endswith(".m4a"):
        aac_path = os.path.join(aac_dir, filename)
        wav_path = os.path.join(wav_dir, os.path.splitext(filename)[0] + ".wav")

        try:
            audio = AudioSegment.from_file(aac_path)
            audio = audio.set_channels(1)        # mono
            audio = audio.set_frame_rate(16000)  # 16 kHz
            audio.export(wav_path, format="wav")
            print(f"✅ Converted: {filename} → {wav_path}")
        except Exception as e:
            print(f"❌ Failed to convert {filename}: {e}")
# Out:
# ✅ Converted: New Recording 65.m4a → /content/drive/MyDrive/fine_tune_data/scream_wav/New Recording 65.wav
# ✅ Converted: New Recording 70.m4a → /content/drive/MyDrive/fine_tune_data/scream_wav/New Recording 70.wav
# ✅ Converted: New Recording 53.m4a → /content/drive/MyDrive/fine_tune_data/scream_wav/New Recording 53.wav
# ✅ Converted: New Recording 54.m4a → /content/drive/MyDrive/fine_tune_data/scream_wav/New Recording 54.wav
# ✅ Converted: New Recording 40.m4a → /content/drive/MyDrive/fine_tune_data/scream_wav/New Recording 40.wav
# ✅ Converted: New Recording 71.m4a → /content/drive/MyDrive/fine_tune_data/scream_wav/New Recording 71.wav
# ✅ Converted: New Recording 51.m4a → /content/drive/MyDrive/fine_tune_data/scream_wav/New Recording 51.wav
# ✅ Converted: New Recording 43.m4a → /content/drive/MyDrive/fine_tune_data/scream_wav/New Recording 43.wav
# ✅ Converted: New Recording 57.m4a → /content/drive/MyDrive/fine_tune_data/scream_wav/New Recording 57.wav
# ✅ Converted: New Recording 59.m4a → /content/drive/MyDrive/fine_tune_data/scream_wav/New Recording 59.wav
# ✅ Converted: New Recording 69.m4a → /content/drive/MyDrive/fine_tune_data/scream_wav/New Recording 69.wav
# ✅ Converted: New Recording 52.m4a → /content/drive/MyDrive/fine_tune_data/scream_wav/New Recording 52.wav
# ✅ Converted: New Recording 41.m4a → /content/drive/MyDrive/fine_tune_data/scream_wav/New Recording 41.wav
# ✅ Converted: New Recording 61.m4a → /content/drive/MyDrive/fine_tune_data/scream_wav/New Recording 61.wav
# ✅ Converted: New Recording 39.m4a → /content/drive/MyDrive/fine_tune_data/scream_wav/New Recording 39.wav
# ✅ Converted: New Recording 50.m4a → /content/drive/MyDrive/fine_tune_data/scream_wav/New Recording 50.wav
# ✅ Converted: New Recording 67.m4a → /content/drive/MyDrive/fine_tune_data/scream_wav/New Recording 67.wav
# ✅ Converted: New Recording 62.m4a → /content/drive/MyDrive/fine_tune_data/scream_wav/New Recording 62.wav
# ✅ Converted: New Recording 63.m4a → /content/drive/MyDrive/fine_tune_data/scream_wav/New Recording 63.wav
# ✅ Converted: New Recording 45.m4a → /content/drive/MyDrive/fine_tune_data/scream_wav/New Recording 45.wav
# ✅ Converted: New Recording 47.m4a → /content/drive/MyDrive/fine_tune_data/scream_wav/New Recording 47.wav
# ✅ Converted: New Recording 66.m4a → /content/drive/MyDrive/fine_tune_data/scream_wav/New Recording 66.wav
# ✅ Converted: New Recording 46.m4a → /content/drive/MyDrive/fine_tune_data/scream_wav/New Recording 46.wav
# ✅ Converted: New Recording 56.m4a → /content/drive/MyDrive/fine_tune_data/scream_wav/New Recording 56.wav
# ✅ Converted: New Recording 48.m4a → /content/drive/MyDrive/fine_tune_data/scream_wav/New Recording 48.wav
# ✅ Converted: New Recording 55.m4a → /content/drive/MyDrive/fine_tune_data/scream_wav/New Recording 55.wav
# ✅ Converted: New Recording 44.m4a → /content/drive/MyDrive/fine_tune_data/scream_wav/New Recording 44.wav
# ✅ Converted: New Recording 42.m4a → /content/drive/MyDrive/fine_tune_data/scream_wav/New Recording 42.wav
# ✅ Converted: New Recording 64.m4a → /content/drive/MyDrive/fine_tune_data/scream_wav/New Recording 64.wav
# ✅ Converted: New Recording 68.m4a → /content/drive/MyDrive/fine_tune_data/scream_wav/New Recording 68.wav
# ✅ Converted: New Recording 60.m4a → /content/drive/MyDrive/fine_tune_data/scream_wav/New Recording 60.wav
# ✅ Converted: New Recording 49.m4a → /content/drive/MyDrive/fine_tune_data/scream_wav/New Recording 49.wav
# ✅ Converted: New Recording 58.m4a → /content/drive/MyDrive/fine_tune_data/scream_wav/New Recording 58.wav
# ✅ Converted: New Recording 72.m4a → /content/drive/MyDrive/fine_tune_data/scream_wav/New Recording 72.wav
# ✅ Converted: New Recording 74.m4a → /content/drive/MyDrive/fine_tune_data/scream_wav/New Recording 74.wav
# ✅ Converted: New Recording 73.m4a → /content/drive/MyDrive/fine_tune_data/scream_wav/New Recording 73.wav
# ✅ Converted: New Recording 81.m4a → /content/drive/MyDrive/fine_tune_data/scream_wav/New Recording 81.wav
# ✅ Converted: New Recording 78.m4a → /content/drive/MyDrive/fine_tune_data/scream_wav/New Recording 78.wav
# ✅ Converted: New Recording 75.m4a → /content/drive/MyDrive/fine_tune_data/scream_wav/New Recording 75.wav
# ✅ Converted: New Recording 76.m4a → /content/drive/MyDrive/fine_tune_data/scream_wav/New Recording 76.wav
# ✅ Converted: New Recording 80.m4a → /content/drive/MyDrive/fine_tune_data/scream_wav/New Recording 80.wav
# ✅ Converted: New Recording 82.m4a → /content/drive/MyDrive/fine_tune_data/scream_wav/New Recording 82.wav
# ✅ Converted: New Recording 79.m4a → /content/drive/MyDrive/fine_tune_data/scream_wav/New Recording 79.wav
# ✅ Converted: New Recording 77.m4a → /content/drive/MyDrive/fine_tune_data/scream_wav/New Recording 77.wav

# %%
import librosa
import numpy as np
import soundfile as sf
import os
import random

# Input/output folders
input_dir = "/content/drive/MyDrive/fine_tune_data/scream_wav"
output_dir = "/content/drive/MyDrive/fine_tune_data/scream_augmented"

# Make sure the output dir exists
os.makedirs(output_dir, exist_ok=True)

# Augmentation functions
def change_volume(audio, factor):
    return audio * factor

def shift_pitch(audio, sr, n_steps):
    return librosa.effects.pitch_shift(audio, sr, n_steps=n_steps)

def add_noise(audio, noise_factor=0.005):
    noise = np.random.randn(len(audio))
    return audio + noise_factor * noise

# Augment and save
for i, filename in enumerate(os.listdir(input_dir)):
    if filename.endswith('.wav'):
        filepath = os.path.join(input_dir, filename)
        try:
            audio, sr = librosa.load(filepath, sr=16000)

            for j in range(2):  # Create 2 augmented versions
                aug_audio = audio.copy()

                if random.random() > 0.5:
                    aug_audio = change_volume(aug_audio, random.uniform(0.7, 1.3))
                if random.random() > 0.5:
                    aug_audio = librosa.effects.pitch_shift(aug_audio, sr=sr, n_steps=random.randint(-2, 2))

                if random.random() > 0.5:
                    aug_audio = add_noise(aug_audio)

                out_path = os.path.join(output_dir, f"help_aug_{i}_{j}.wav")
                sf.write(out_path, aug_audio, sr)
                print(f"✅ Augmented: {out_path}")

        except Exception as e:
            print(f"❌ Error processing {filename}: {e}")
# Out:
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_0_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_0_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_1_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_1_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_2_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_2_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_3_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_3_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_4_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_4_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_5_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_5_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_6_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_6_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_7_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_7_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_8_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_8_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_9_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_9_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_10_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_10_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_11_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_11_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_12_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_12_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_13_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_13_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_14_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_14_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_15_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_15_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_16_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_16_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_17_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_17_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_18_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_18_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_19_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_19_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_20_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_20_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_21_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_21_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_22_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_22_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_23_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_23_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_24_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_24_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_25_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_25_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_26_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_26_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_27_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_27_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_28_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_28_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_29_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_29_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_30_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_30_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_31_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_31_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_32_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_32_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_33_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_33_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_34_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_34_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_35_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_35_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_36_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_36_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_37_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_37_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_38_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_38_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_39_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_39_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_40_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_40_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_41_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_41_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_42_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_42_1.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_43_0.wav
# ✅ Augmented: /content/drive/MyDrive/fine_tune_data/scream_augmented/help_aug_43_1.wav
